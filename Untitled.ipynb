# %%
import pandas as pd

# %%
data = pd.read_csv("report1552487763147.csv.csv", encoding="latin-1")

# %%
data.head()
# Out:
#   Salutation First Name  Last Name  \
# 0        NaN     Andrew      Nadin
# 1        NaN    Stanley  Gorodesky
# 2        NaN       Jyll    Bascone
# 3        NaN        Joy      Petty
# 4        NaN    Gissell  Malfitano
#
#                                                Title    Mailing Street  \
# 0                            Chief Marketing Officer               NaN
# 1  Senior Vice President of Corporate Business De...               NaN
# 2        Senior Director of Marketing and Admissions               NaN
# 3                                                NaN               NaN
# 4                              Director Of Marketing  885 Teaneck Road
#
#   Mailing City Mailing Zip/Postal Code Mailing State/Province (text only)  \
# 0          NaN                     NaN                                NaN
# 1          NaN                     NaN                                NaN
# 2     New York                     NaN                           New York
# ...
